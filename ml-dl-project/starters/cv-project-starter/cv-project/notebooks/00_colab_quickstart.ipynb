# %% [markdown]
# # CV Starter — Colab/Kaggle Quickstart
#
# > Author : Badr TAJINI
#
# **Academic year:** 2025–2026
# **School:** ECE
# **Course:** Machine Learning & Deep Learning
#
# ---
#
#
# Welcome! This notebook is intentionally beginner-friendly. Follow the steps exactly and you will confirm that the starter project works on a free GPU runtime.
#
# ### Before you run anything
# 1. **Open the notebook in Google Colab or Kaggle.**
# 2. **Change the hardware accelerator to GPU (T4 preferred).**
#    * Colab: `Runtime` → `Change runtime type` → Hardware accelerator `GPU` → Save.
#    * Kaggle: `Settings` (gear icon) → Turn on `Accelerator` → Choose `T4 x1`.
# 3. Once the GPU is enabled, run the cells **from top to bottom**. Every code cell has comments explaining what it does.
#
# The notebook will: (a) check that a GPU is available, (b) install dependencies, (c) run a quick smoke test that loads CIFAR-10 and performs one training step, and (d) show you how to launch the full training/evaluation commands when you are ready for longer experiments.

# %% [markdown]
# ## 0. Project files
#
# - Option A: `git clone <your_repo_url> cv-project`
# - Option B: Upload the `cv-project` folder via the left sidebar (ensure the root is `/content/cv-project`).
#
# Run the cell below afterwards; it will raise a helpful error if the folder is missing.

# %% [markdown]
# ### Quick checklist before running code
#
# - **Colab:** Go to `Runtime → Change runtime type`, pick `GPU`, and click **Save**.
# - **Kaggle:** Open the gear icon in the top-right, enable **Accelerator**, and choose `T4 x1`.
# - Wait for the runtime to restart (Colab shows `Connected` again).
# - Then run every cell in order. If you see an error, stop, read the message, and re-run the cell after fixing the issue.
#
# Once the smoke test succeeds you can run the full training and evaluation commands shown at the end of the notebook.

# %% [markdown]
# ### How to run a cell
# - Click the little ▶️ button on the left of a cell, or press **Shift + Enter** (Colab) / **Ctrl + Enter** (Kaggle).
# - Wait for the cell to finish (a number like `[1]` appears once it is done).
# - If a cell shows an error, read the message, fix the issue, and re-run that same cell before moving forward.

# %% [markdown]
# ### Step 0 — Confirm the GPU is ready
# Run the next cell. You should see a table with GPU details (name + memory).
# If you get the message `nvidia-smi unavailable`, the runtime is still on CPU—go back to the checklist above and switch it to GPU, then rerun the cell.

# %%
# !nvidia-smi || echo "nvidia-smi unavailable (CPU runtime)"
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# nvidia-smi unavailable (CPU runtime)

# %% [markdown]
# ### Step 1 — Point the notebook at the project folder
# This cell makes sure Colab/Kaggle is looking at the `cv-project` directory.
# If it raises a `FileNotFoundError`, you likely uploaded the folder to a different place. Use the file browser on the left to confirm the path, fix it, and rerun the cell.

# %%
import os
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent.resolve()
elif PROJECT_ROOT.name == "content":
    candidate = PROJECT_ROOT / "cv-project"
    if candidate.exists():
        PROJECT_ROOT = candidate.resolve()

if not (PROJECT_ROOT / "src").exists():
    raise FileNotFoundError(
        f"Could not locate project root at {PROJECT_ROOT}. Clone or upload cv-project before proceeding."
    )

os.chdir(PROJECT_ROOT)
if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.append(str(PROJECT_ROOT / "src"))
print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: /mnt/c/Users/alexa/ING_4/Semestre_8/Machine_Learning/ml-dl-project/ml-dl-project/starters/cv-project-starter/cv-project

# %% [markdown]
# ### Step 2 — Install the project requirements
# This command reads `requirements.txt` and installs exactly the same packages you would get locally.
# Expect a lot of text output; that is normal. If installation fails, run the cell again before moving forward.

# %%
# Install project dependencies listed in requirements.txt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: torchvision in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.25.0)
# Collecting torchmetrics==1.4.0 (from -r requirements.txt (line 3))
#   Downloading torchmetrics-1.4.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pyyaml in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (6.0.3)
# Collecting tqdm (from -r requirements.txt (line 5))
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: matplotlib in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (3.10.8)
# Collecting seaborn (from -r requirements.txt (line 7))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn (from -r requirements.txt (line 8))
#   Downloading scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>1.20.0 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torchmetrics==1.4.0->-r requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: packaging>17.1 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torchmetrics==1.4.0->-r requirements.txt (line 3)) (25.0)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics==1.4.0->-r requirements.txt (line 3))
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting pretty-errors==1.2.25 (from torchmetrics==1.4.0->-r requirements.txt (line 3))
#   Downloading pretty_errors-1.2.25-py3-none-any.whl.metadata (12 kB)
# Collecting colorama (from pretty-errors==1.2.25->torchmetrics==1.4.0->-r requirements.txt (line 3))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: filelock in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (2026.1.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torch->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from cuda-bindings==12.9.4->torch->-r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from torchvision->-r requirements.txt (line 2)) (12.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 6)) (2.9.0.post0)
# Collecting pandas>=1.2 (from seaborn->-r requirements.txt (line 7))
#   Downloading pandas-3.0.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting scipy>=1.10.0 (from scikit-learn->-r requirements.txt (line 8))
#   Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn->-r requirements.txt (line 8))
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->-r requirements.txt (line 8))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages (from jinja2->torch->-r requirements.txt (line 1)) (3.0.2)
# Downloading torchmetrics-1.4.0-py3-none-any.whl (868 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 9.1 MB/s  0:00:00
# Downloading pretty_errors-1.2.25-py3-none-any.whl (17 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 11.3 MB/s  0:00:00m0:00:0100:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading pandas-3.0.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 11.5 MB/s  0:00:00eta 0:00:01
# Downloading scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 11.5 MB/s  0:00:03m0:00:0100:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: tqdm, threadpoolctl, scipy, lightning-utilities, joblib, colorama, scikit-learn, pretty-errors, pandas, seaborn, torchmetrics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [torchmetrics] [torchmetrics]lities]
# Successfully installed colorama-0.4.6 joblib-1.5.3 lightning-utilities-0.15.3 pandas-3.0.1 pretty-errors-1.2.25 scikit-learn-1.8.0 scipy-1.17.1 seaborn-0.13.2 threadpoolctl-3.6.0 torchmetrics-1.4.0 tqdm-4.67.3

# %% [markdown]
# ### Step 3 — Run the smoke test
# This quick check downloads CIFAR-10 (if needed), runs one mini-batch through the model, and saves `outputs/smoke_metrics.json`.
# You should see a short JSON output such as `{"loss": ..., "batch_size": 64, ...}`.
# If you hit a download or network error, wait a few seconds and re-run the cell; Colab sometimes needs a second try.

# %%
from src import smoke_check

smoke_path = smoke_check.run_smoke("configs/cv_cifar10_fast.yaml")
print(smoke_path.read_text())
# Out:
# /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/alexa/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:04<00:00, 11.6MB/s]
# /home/alexa/miniconda3/envs/labs-2025/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# {
#   "loss": 2.648369312286377,
#   "batch_size": 64,
#   "num_classes": 10,
#   "device": "cpu"
# }

# %% [markdown]
# > **Why run the smoke test?**
#
# > The smoke test is a safety check before long training. It loads CIFAR‑10, runs a single forward/backward pass, and writes outputs/smoke_metrics.json. If this succeeds, you know:
#
# > - the dataset can be downloaded/read,
# > - the model compiles and runs on your GPU,
# > - dependencies are installed correctly.
# >
# > In short, if it fails, fix the error (missing folder, bad install, no GPU) before investing time in a full training run :
# >
# > *After !python src/evaluate.py ... (Step 4 below)*

# %% [markdown]
# ## 1. Review smoke-test output
# - Confirm the previous cell printed a JSON block (loss, batch size, device).
# - You should now see `outputs/smoke_metrics.json` in the file browser on the left.
# - Need only a quick check? You can stop here. Ready for real training? Continue to Section 2 below.
# - If anything failed, read the error message carefully, fix the issue, and re-run the smoke cell before moving on.

# %% [markdown]
# ## 2. Full training run (optional)
# Only run these cells when you want the complete experiment. On the first run PyTorch will also download CIFAR-10, so the first epoch may start slowly.
#
# **Before running:**
# 1. Open `configs/cv_cifar10.yaml` (Menu → File → Open …) if you want to change hyperparameters.
# 2. Ensure the runtime still shows a GPU connection.
# 3. Close other browser tabs or notebooks to avoid memory pressure.

# %%
# Train the model using the main configuration file. Expect visible progress bars.
# The first time you run this it will also download CIFAR-10, so the progress bar
# might pause around 0% while data is fetched.
# !python src/train.py --config configs/cv_cifar10.yaml

# %%
# Evaluate the best checkpoint produced during training.
# This will print accuracy and write the metrics/plots listed below.
# !python src/evaluate.py --config configs/cv_cifar10.yaml --ckpt outputs/best.pt

# %% [markdown]
# ### Step 4 — What should I see now?
# - `outputs/best.pt`: saved checkpoint.
# - `outputs/log.csv`: training history (loss/accuracy per epoch).
# - `outputs/eval.json`, `per_class_metrics.csv`, `confusion_matrix.png`, `leaderboard.png`: evaluation artefacts.
#
# If any of these files are missing, scroll up for errors in the training/evaluation cells.

# %% [markdown]
# ## 3. Mirror this workflow for other tracks
#
# 1. Duplicate this notebook and rename it (e.g., `00_nlp_quickstart.ipynb`).
# 2. Copy the corresponding starter folder into your Colab/Kaggle workspace (`nlp-project`, `od-project`, `ts-project`).
# 3. Update the install cell so it matches that starter's `requirements.txt`.
# 4. Replace `from src import smoke_check` with the helper module provided in the new starter (each repo ships with one).
# 5. Point the train/eval commands at the new `configs/*.yaml` file.
# 6. Optionally tweak the markdown text so instructions mention the right dataset and metrics.
#
# By following the same structure—GPU check → install → smoke test → full run—students can master all four tracks with a consistent workflow.
